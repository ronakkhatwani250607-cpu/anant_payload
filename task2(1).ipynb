# %% [markdown]
# <a href="https://colab.research.google.com/github/ronakkhatwani250607-cpu/anant_payload/blob/main/task2(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Soil Classification CNN
# ## Modified: 4-Band Input reshaped as 2×2 Band Matrix
#
# ### Pipeline overview
# ```
# (N, 128, 128, 3)     ← original RGB
#        ↓  add redundant 4th band (Red channel copy)
# (N, 128, 128, 4)     ← 4 bands stacked flat
#        ↓  reshape band axis: 4 → (2, 2)
# (N, 128, 128, 2, 2)  ← 4 bands arranged as a 2×2 matrix per pixel
#        ↓  Conv3D learns joint spatial-spectral features
# ```
#
# Band layout after reshape:
# ```
# ┌───┬────┐
# │ R │ G  │
# ├───┼────┤
# │ B │ R* │   (* = redundant Red band)
# └───┴────┘
# ```

# %%
# !pip install tensorflow
# !pip install kagglehub

# %%
# Standard survival kit for any ML project
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Classic ML tools
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

# TensorFlow = our deep learning engine
import tensorflow as tf

# Layers used to build the CNN brain
from tensorflow.keras.layers import (
    Dense, Dropout, GlobalAveragePooling3D,
    Conv3D, BatchNormalization, MaxPooling3D
)

# Training helpers that stop the model from overthinking
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Converts labels → one-hot format (because neural nets are picky eaters)
from tensorflow.keras.utils import to_categorical

# Kagglehub lets us download datasets without manually clicking 17 buttons
import kagglehub

# Download dataset from Kaggle automatically
# (because manually downloading datasets is so 2012)
path = kagglehub.dataset_download("ai4a-lab/comprehensive-soil-classification-datasets")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'comprehensive-soil-classification-datasets' dataset.
# Path to dataset files: /kaggle/input/comprehensive-soil-classification-datasets

# %%
# Dataset root folder
root_path = os.path.join(path, "CyAUG-Dataset")

# Each directory corresponds to one soil class
dirs = sorted(os.listdir(root_path))

# Lists to store images and labels
X, y = [], []

IMG_SIZE = 64  # Downscale images to make training faster (GPU says thank you)

for idx, soil_class in enumerate(dirs):

    # Navigate inside each class folder
    class_path = os.path.join(root_path, soil_class)

    for file in os.listdir(class_path):

        img_path = os.path.join(class_path, file)

        # Load image and resize
        img = tf.keras.preprocessing.image.load_img(
            img_path,
            target_size=(IMG_SIZE, IMG_SIZE)
        )

        # Convert PIL image → numpy array
        img = tf.keras.preprocessing.image.img_to_array(img)

        # Store data
        X.append(img)
        y.append(idx)

# Convert Python lists → NumPy arrays
X = np.array(X)
y = np.array(y)

print("X shape (original):", X.shape)
print("y shape:", y.shape)
print("Classes:", dirs)
# Out:
# X shape (original): (5097, 64, 64, 3)
# y shape: (5097,)
# Classes: ['Alluvial_Soil', 'Arid_Soil', 'Black_Soil', 'Laterite_Soil', 'Mountain_Soil', 'Red_Soil', 'Yellow_Soil']

# %%
# Check if dataset is balanced
# (Spoiler: it usually isn't)
_, counts = np.unique(y, return_counts=True)

plt.bar(dirs, counts)
plt.xticks(rotation=45)
plt.title("Soil Class Distribution")

# This plot tells us which soil types are under-represented
plt.show()

# %%
from collections import Counter

# This function slightly distorts images to create new training samples
# Think of it as "creative cloning"

def augment_image(img):

    h, w = img.shape[0], img.shape[1]

    # Flatten band structure temporarily
    img_flat = img.reshape(h, w, 4)

    # Random horizontal flip
    if np.random.rand() > 0.5:
        img_flat = np.fliplr(img_flat)

    # Random vertical flip
    if np.random.rand() > 0.5:
        img_flat = np.flipud(img_flat)

    # Random brightness adjustment
    # Because lighting conditions in the real world are chaotic
    factor = 1.0 + np.random.uniform(-0.1, 0.1)
    img_flat = np.clip(img_flat * factor, 0, 255)

    # Random rotation (0°, 90°, 180°, 270°)
    k = np.random.choice([0, 1, 2, 3])
    img_flat = np.rot90(img_flat, k=k)

    # Restore band matrix structure
    return img_flat.reshape(h, w, 2, 2)

# Some soil classes appear less frequently
# Neural networks hate unfair situations
# So we duplicate + augment rare classes

from collections import Counter

def oversample_to_balance(X, y):

    class_counts = Counter(y)
    max_count = max(class_counts.values())

    X_out, y_out = list(X), list(y)

    for cls, count in class_counts.items():

        if count < max_count:

            cls_idx = np.where(y == cls)[0]

            # Create synthetic samples until class sizes match
            for _ in range(max_count - count):

                aug = augment_image(X[np.random.choice(cls_idx)])

                X_out.append(aug)
                y_out.append(cls)

    # Shuffle dataset so augmented samples are mixed
    X_out, y_out = np.array(X_out), np.array(y_out)
    perm = np.random.permutation(len(y_out))

    return X_out[perm], y_out[perm]

# %% [markdown]
# ## Step 1 — Add Redundant 4th Band
#
# Duplicate the **Red channel (index 0)** as a 4th band.
#
# ```
# (N, 128, 128, 3)  →  (N, 128, 128, 4)
# ```

# %%
# Our original image has only 3 bands (RGB)
# But Conv3D works nicer with a square band structure

# So we duplicate the Red channel
# Yes, it is slightly redundant
# But it lets us build a 2×2 spectral matrix per pixel

red_channel = X[:, :, :, 0:1]

X_4band = np.concatenate([X, red_channel], axis=-1)

print("X_4band shape:", X_4band.shape)
# Out:
# X_4band shape: (5097, 64, 64, 4)

# %% [markdown]
# ## Step 2 — Reshape Band Axis: flat (4,) → square (2, 2)
#
# Instead of treating the 4 bands as a flat vector, we arrange them as a **2×2 matrix**.
# This is a pure reshape — **no information is lost**.
#
# ```
# Flat (4,):             2×2 matrix:
# [ R, G, B, R* ]  →    ┌───┬────┐
#                        │ R │ G  │
#                        ├───┼────┤
#                        │ B │ R* │
#                        └───┴────┘
#
# (N, 128, 128, 4)  →   (N, 128, 128, 2, 2)
# ```

# %%
N, H, W, C = X_4band.shape

X_sq = X_4band.reshape(N, H, W, 2, 2)

print("X_sq shape:", X_sq.shape)

# Sanity check: make sure reshape didn't corrupt data
assert np.array_equal(
    X_sq[0,0,0].flatten(),
    X_4band[0,0,0]
)

print("Sanity check passed — reshape is lossless.")

# Show the 2x2 band matrix for one pixel
print("\nBand layout (2×2) for pixel (0,0) of image 0:")
print(X_sq[0, 0, 0])
print("Flat (original):", X_4band[0, 0, 0])
# Out:
# X_sq shape: (5097, 64, 64, 2, 2)
# Sanity check passed — reshape is lossless.
#
# Band layout (2×2) for pixel (0,0) of image 0:
# [[132.  93.]
#  [ 50. 132.]]
# Flat (original): [132.  93.  50. 132.]

# %% [markdown]
# ## Step 3 — Train / Val / Test Split

# %%
num_classes = len(dirs)
y_cat = to_categorical(y, num_classes=num_classes)

# Carve out test set from ORIGINAL data only (no augmented images in test)
X_trainval, X_test, y_trainval, y_test_raw = train_test_split(
    X_sq, y, test_size=0.15, stratify=y, random_state=42
)

# Oversample only train+val
X_trainval_bal, y_trainval_bal = oversample_to_balance(X_trainval, y_trainval)

# Split into train/val
y_tv_cat = to_categorical(y_trainval_bal, num_classes=num_classes)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval_bal, y_tv_cat, test_size=0.15,
    stratify=y_trainval_bal, random_state=42
)
y_test = to_categorical(y_test_raw, num_classes=num_classes)

print(f"Train : {X_train.shape}")
print(f"Val   : {X_val.shape}")
print(f"Test  : {X_test.shape}")
# Out:
# Train : (7086, 64, 64, 2, 2)
# Val   : (1251, 64, 64, 2, 2)
# Test  : (765, 64, 64, 2, 2)

# %%
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(np.argmax(y_train, axis=1)),
    y=np.argmax(y_train, axis=1)
)

class_weights[0] *= 2
class_weights[1] *= 3
class_weights[3] *= 3
class_weights[4] *= 2
class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: np.float64(1.9985897616697221), 1: np.float64(2.9978846425045833), 2: np.float64(1.0002823263692828), 3: np.float64(3.0008469791078483), 4: np.float64(2.0005646527385657), 5: np.float64(1.0002823263692828), 6: np.float64(1.0002823263692828)}

# %% [markdown]
# ## Step 4 — Model Architecture (Conv3D)
#
# Input shape `(128, 128, 2, 2)` has **two spatial axes** (H, W) and **two band axes** (band_row, band_col).
#
# **Conv3D** treats the tensor as a 3D volume: `(H, W, band_row)`, sliding a kernel across
# all three axes simultaneously. This lets it learn **joint spatial-spectral patterns**.
#
# ```
# Input  (128, 128, 2, 2)
#   │
# Conv3D(32,  kernel 3×3×2)  →  (128, 128, 1, 32)   # collapses band_row
# MaxPool3D(2×2×1)           →  ( 64,  64, 1, 32)
#   │
# Conv3D(64,  kernel 3×3×1)  →  ( 64,  64, 1, 64)
# MaxPool3D(2×2×1)           →  ( 32,  32, 1, 64)
#   │
# Conv3D(128, kernel 3×3×1)  →  ( 32,  32, 1, 128)
# MaxPool3D(2×2×1)           →  ( 16,  16, 1, 128)
#   │
# Conv3D(256, kernel 3×3×1)
#   │
# GlobalAveragePooling3D     →  (256,)
#   │
# Dense(256) → Dense(7, softmax)
# ```

# %%
# tf.data makes training faster by:
# batching
# caching
# prefetching

# In short: fewer GPU coffee breaks

inputs = tf.keras.Input(shape=(H, W, 2, 2))   # (128, 128, 2, 2)

# Block 1 — kernel (3,3,2) collapses both band rows at once
x = Conv3D(32, kernel_size=(3, 3, 2), padding='same', activation='relu')(inputs)
x = BatchNormalization()(x)
x = MaxPooling3D(pool_size=(2, 2, 1))(x)   # → (64, 64, 2, 32)
x = Dropout(0.1)(x)

# Block 2
x = Conv3D(64, kernel_size=(3, 3, 2), padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling3D(pool_size=(2, 2, 1))(x)   # → (32, 32, 2, 64)
x = Dropout(0.15)(x)

# Block 3 — pool_size (2,2,2) collapses remaining band dim
x = Conv3D(128, kernel_size=(3, 3, 2), padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling3D(pool_size=(2, 2, 2))(x)   # → (16, 16, 1, 128)
x = Dropout(0.2)(x)

# Block 4
x = Conv3D(256, kernel_size=(3, 3, 1), padding='same', activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.25)(x)

# Head
x = GlobalAveragePooling3D()(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 2, 2)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d (Conv3D)                 │ (None, 64, 64, 2, 32)  │         1,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 2, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 32, 32, 2, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 32, 2, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 32, 32, 2, 64)  │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 2, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 16, 16, 2, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 16, 2, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 16, 16, 2, 128) │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 2, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 8, 8, 1, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 8, 1, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 8, 8, 1, 256)   │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 1, 256)   │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 1, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling3d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling3D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 550,375 (2.10 MB)
#  Trainable params: 549,415 (2.10 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
class MacroF1Score(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name='macro_f1', **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.tp = self.add_weight(shape=(num_classes,), initializer='zeros', name='tp') #true positive
        self.fp = self.add_weight(shape=(num_classes,), initializer='zeros', name='fp') #false positive
        self.fn = self.add_weight(shape=(num_classes,), initializer='zeros', name='fn') #false negative

    def update_state(self, y_true, y_pred, sample_weight=None):
        yp = tf.one_hot(tf.argmax(y_pred, axis=1), self.num_classes)  # (B, C)
        yt = tf.one_hot(tf.argmax(y_true, axis=1), self.num_classes)  # (B, C)

        # Sum over batch dimension → shape (C,)
        self.tp.assign_add(tf.reduce_sum(yp * yt,       axis=0))
        self.fp.assign_add(tf.reduce_sum(yp * (1 - yt), axis=0))
        self.fn.assign_add(tf.reduce_sum((1 - yp) * yt, axis=0))

    def result(self):
        p  = self.tp / (self.tp + self.fp + 1e-7)
        r  = self.tp / (self.tp + self.fn + 1e-7)
        return tf.reduce_mean(2 * p * r / (p + r + 1e-7))

    def reset_state(self):
        self.tp.assign(tf.zeros(self.num_classes))
        self.fp.assign(tf.zeros(self.num_classes))
        self.fn.assign(tf.zeros(self.num_classes))
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy', MacroF1Score(num_classes)]
)

callbacks = [
    EarlyStopping(monitor='val_macro_f1', patience=8,
                  restore_best_weights=True, mode='max'),
    ReduceLROnPlateau(monitor='val_macro_f1', patience=4, mode='max')
]

# %%
# callbacks = [
#     EarlyStopping(patience=8, restore_best_weights=True),
#     ReduceLROnPlateau(patience=4)
# ]

# %% [markdown]
# ## Step 5 — Training with tf.data Pipeline

# %%
BATCH_SIZE = 64
AUTOTUNE   = tf.data.AUTOTUNE

def make_dataset(X, y, shuffle=True):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    if shuffle:
        ds = ds.shuffle(buffer_size=len(X), seed=42)
    return ds.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)

train_ds = make_dataset(X_train, y_train, shuffle=True)
val_ds   = make_dataset(X_val,   y_val)
test_ds  = make_dataset(X_test,  y_test)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=40,
    class_weight=class_weights,
    callbacks=callbacks,
)
# Out:
# Epoch 1/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 44s 246ms/step - accuracy: 0.6696 - loss: 1.7611 - macro_f1: 0.6737 - val_accuracy: 0.3957 - val_loss: 3.7517 - val_macro_f1: 0.3380 - learning_rate: 0.0010
# Epoch 2/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.8164 - loss: 1.1036 - macro_f1: 0.8177 - val_accuracy: 0.7946 - val_loss: 0.6006 - val_macro_f1: 0.7862 - learning_rate: 0.0010
# Epoch 3/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.8383 - loss: 0.9299 - macro_f1: 0.8394 - val_accuracy: 0.8697 - val_loss: 0.3898 - val_macro_f1: 0.8706 - learning_rate: 0.0010
# Epoch 4/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.8639 - loss: 0.8263 - macro_f1: 0.8648 - val_accuracy: 0.7146 - val_loss: 0.8239 - val_macro_f1: 0.7081 - learning_rate: 0.0010
# Epoch 5/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - accuracy: 0.8667 - loss: 0.8113 - macro_f1: 0.8679 - val_accuracy: 0.8473 - val_loss: 0.4701 - val_macro_f1: 0.8486 - learning_rate: 0.0010
# Epoch 6/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.8806 - loss: 0.7109 - macro_f1: 0.8810 - val_accuracy: 0.8873 - val_loss: 0.2915 - val_macro_f1: 0.8861 - learning_rate: 0.0010
# Epoch 7/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 122ms/step - accuracy: 0.8786 - loss: 0.6969 - macro_f1: 0.8791 - val_accuracy: 0.8657 - val_loss: 0.3744 - val_macro_f1: 0.8660 - learning_rate: 0.0010
# Epoch 8/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 123ms/step - accuracy: 0.8907 - loss: 0.6466 - macro_f1: 0.8912 - val_accuracy: 0.7554 - val_loss: 0.7340 - val_macro_f1: 0.7597 - learning_rate: 0.0010
# Epoch 9/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - accuracy: 0.8841 - loss: 0.6610 - macro_f1: 0.8849 - val_accuracy: 0.8849 - val_loss: 0.3519 - val_macro_f1: 0.8808 - learning_rate: 0.0010
# Epoch 10/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - accuracy: 0.9102 - loss: 0.5590 - macro_f1: 0.9104 - val_accuracy: 0.8433 - val_loss: 0.4709 - val_macro_f1: 0.8385 - learning_rate: 0.0010
# Epoch 11/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - accuracy: 0.9215 - loss: 0.4950 - macro_f1: 0.9218 - val_accuracy: 0.9313 - val_loss: 0.2059 - val_macro_f1: 0.9313 - learning_rate: 1.0000e-04
# Epoch 12/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9289 - loss: 0.4328 - macro_f1: 0.9292 - val_accuracy: 0.9265 - val_loss: 0.2158 - val_macro_f1: 0.9267 - learning_rate: 1.0000e-04
# Epoch 13/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9293 - loss: 0.4184 - macro_f1: 0.9292 - val_accuracy: 0.9257 - val_loss: 0.2165 - val_macro_f1: 0.9262 - learning_rate: 1.0000e-04
# Epoch 14/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9307 - loss: 0.4106 - macro_f1: 0.9307 - val_accuracy: 0.9249 - val_loss: 0.2245 - val_macro_f1: 0.9252 - learning_rate: 1.0000e-04
# Epoch 15/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9332 - loss: 0.3991 - macro_f1: 0.9332 - val_accuracy: 0.9273 - val_loss: 0.2198 - val_macro_f1: 0.9278 - learning_rate: 1.0000e-04
# Epoch 16/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9376 - loss: 0.3798 - macro_f1: 0.9378 - val_accuracy: 0.9345 - val_loss: 0.2038 - val_macro_f1: 0.9342 - learning_rate: 1.0000e-05
# Epoch 17/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - accuracy: 0.9463 - loss: 0.3705 - macro_f1: 0.9462 - val_accuracy: 0.9361 - val_loss: 0.1972 - val_macro_f1: 0.9357 - learning_rate: 1.0000e-05
# Epoch 18/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9456 - loss: 0.3590 - macro_f1: 0.9456 - val_accuracy: 0.9369 - val_loss: 0.1928 - val_macro_f1: 0.9365 - learning_rate: 1.0000e-05
# Epoch 19/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - accuracy: 0.9443 - loss: 0.3610 - macro_f1: 0.9441 - val_accuracy: 0.9369 - val_loss: 0.1896 - val_macro_f1: 0.9366 - learning_rate: 1.0000e-05
# Epoch 20/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - accuracy: 0.9431 - loss: 0.3659 - macro_f1: 0.9430 - val_accuracy: 0.9369 - val_loss: 0.1919 - val_macro_f1: 0.9365 - learning_rate: 1.0000e-05
# Epoch 21/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9438 - loss: 0.3565 - macro_f1: 0.9435 - val_accuracy: 0.9369 - val_loss: 0.1950 - val_macro_f1: 0.9364 - learning_rate: 1.0000e-05
# Epoch 22/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 127ms/step - accuracy: 0.9445 - loss: 0.3563 - macro_f1: 0.9444 - val_accuracy: 0.9392 - val_loss: 0.1888 - val_macro_f1: 0.9390 - learning_rate: 1.0000e-05
# Epoch 23/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 127ms/step - accuracy: 0.9392 - loss: 0.3559 - macro_f1: 0.9391 - val_accuracy: 0.9384 - val_loss: 0.1894 - val_macro_f1: 0.9382 - learning_rate: 1.0000e-05
# Epoch 24/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9452 - loss: 0.3585 - macro_f1: 0.9449 - val_accuracy: 0.9353 - val_loss: 0.1933 - val_macro_f1: 0.9349 - learning_rate: 1.0000e-05
# Epoch 25/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9445 - loss: 0.3574 - macro_f1: 0.9443 - val_accuracy: 0.9384 - val_loss: 0.1863 - val_macro_f1: 0.9383 - learning_rate: 1.0000e-05
# Epoch 26/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9450 - loss: 0.3478 - macro_f1: 0.9449 - val_accuracy: 0.9376 - val_loss: 0.1881 - val_macro_f1: 0.9374 - learning_rate: 1.0000e-05
# Epoch 27/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - accuracy: 0.9445 - loss: 0.3446 - macro_f1: 0.9445 - val_accuracy: 0.9376 - val_loss: 0.1873 - val_macro_f1: 0.9374 - learning_rate: 1.0000e-06
# Epoch 28/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 125ms/step - accuracy: 0.9453 - loss: 0.3415 - macro_f1: 0.9452 - val_accuracy: 0.9376 - val_loss: 0.1871 - val_macro_f1: 0.9374 - learning_rate: 1.0000e-06
# Epoch 29/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.9447 - loss: 0.3528 - macro_f1: 0.9447 - val_accuracy: 0.9376 - val_loss: 0.1861 - val_macro_f1: 0.9374 - learning_rate: 1.0000e-06
# Epoch 30/40
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.9451 - loss: 0.3466 - macro_f1: 0.9448 - val_accuracy: 0.9376 - val_loss: 0.1869 - val_macro_f1: 0.9374 - learning_rate: 1.0000e-06

# %%
plt.plot(history.history['accuracy'],     label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
# plt.plot(history.history['val_macro_f1'],        label='F1 Score Val')
# plt.plot(history.history['macro_f1'],        label='F1 Score')
plt.legend()
plt.title("Accuracy Curve")
plt.show()



# plt.plot(history.history['accuracy'],     label='Train')
# plt.plot(history.history['val_accuracy'], label='Val')
plt.plot(history.history['val_macro_f1'],        label='F1 Score Val')
plt.plot(history.history['macro_f1'],        label='F1 Score')
plt.legend()
plt.title("Accuracy Curve")
plt.show()

# %%
model.evaluate(test_ds)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.9493 - loss: 0.1774 - macro_f1: 0.8660
# [0.20895951986312866, 0.943790853023529, 0.8779892325401306]

# %%
# y_pred = model.predict(test_ds)

# f1 = f1_score(
#     np.argmax(y_test, axis=1),
#     np.argmax(y_pred, axis=1),
#     average='macro'
# )
# print("Macro F1:", round(f1, 4))

# %%
from collections import Counter

# Step 1 — collect predictions and labels directly from dataset
y_true_list, y_pred_list = [], []

for X_batch, y_batch in test_ds:
    preds = model.predict(X_batch, verbose=0)
    y_pred_list.append(preds)
    y_true_list.append(y_batch.numpy())

y_pred_all = np.argmax(np.concatenate(y_pred_list), axis=1)
y_true_all = np.argmax(np.concatenate(y_true_list), axis=1)

# Step 2 — check distributions
print("Predicted class distribution:", Counter(y_pred_all))
print("True class distribution:     ", Counter(y_true_all))

# Step 3 — check if model is just guessing one class
unique_preds = len(set(y_pred_all.tolist()))
print(f"\nModel is predicting {unique_preds} distinct classes out of {num_classes}")

# Step 4 — per class F1
from sklearn.metrics import classification_report
print("\n", classification_report(y_true_all, y_pred_all, target_names=dirs))
# Out:
# Predicted class distribution: Counter({np.int64(6): 207, np.int64(2): 176, np.int64(5): 164, np.int64(0): 107, np.int64(1): 48, np.int64(3): 38, np.int64(4): 25})
# True class distribution:      Counter({np.int64(6): 210, np.int64(2): 176, np.int64(5): 169, np.int64(0): 104, np.int64(1): 43, np.int64(3): 33, np.int64(4): 30})
#
# Model is predicting 7 distinct classes out of 7
#
#                 precision    recall  f1-score   support
#
# Alluvial_Soil       0.90      0.92      0.91       104
#     Arid_Soil       0.73      0.81      0.77        43
#    Black_Soil       0.99      0.99      0.99       176
# Laterite_Soil       0.66      0.76      0.70        33
# Mountain_Soil       0.88      0.73      0.80        30
#      Red_Soil       1.00      0.97      0.98       169
#   Yellow_Soil       0.99      0.98      0.98       210
#
#      accuracy                           0.94       765
#     macro avg       0.88      0.88      0.88       765
#  weighted avg       0.95      0.94      0.94       765

# %%
# cm = confusion_matrix(
#     np.argmax(y_test, axis=1),
#     np.argmax(y_pred, axis=1)
# )

# sns.heatmap(cm, annot=True, fmt='d', xticklabels=dirs, yticklabels=dirs)
# plt.xlabel("Predicted")
# plt.ylabel("True")
# plt.title("Confusion Matrix")
# plt.show()

# %%
cm = confusion_matrix(y_true_all, y_pred_all)

plt.figure()
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    xticklabels=dirs,
    yticklabels=dirs,
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
model.save("best_soil_classifier_2x2bands.keras")
